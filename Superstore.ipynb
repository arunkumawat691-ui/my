# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_excel(r"C:\Users\Admin\OneDrive\Desktop\Superstore.xlsx")
df = pd.DataFrame(data)

# %%
df.head()
# Out:
#   Order Date         Category Sub-Category Region  Product Name  Sales  Profit
# 0 2023-01-05        Furniture        Chair  North  Office Chair    200      50
# 1 2023-01-10       Technology        Phone  South        iPhone    800     200
# 2 2023-02-15  Office Supplies        Paper   East      A4 Paper     50      10
# 3 2023-02-20        Furniture        Table   West    Wood Table    300     -20
# 4 2023-03-05       Technology       Laptop  North   Dell Laptop   1200     300

# %%
df.isnull().sum()
df.dropna(inplace=True)

# %%
df['Month'] = df['Order Date'].dt.month_name()

# %%
df['profit_status'] = df["Profit"].apply(lambda x:"loss" if x < 0 else "Profit")
df
# Out:
#    Order Date         Category Sub-Category Region   Product Name  Sales  \
# 0  2023-01-05        Furniture        Chair  North   Office Chair    200
# 1  2023-01-10       Technology        Phone  South         iPhone    800
# 2  2023-02-15  Office Supplies        Paper   East       A4 Paper     50
# 3  2023-02-20        Furniture        Table   West     Wood Table    300
# 4  2023-03-05       Technology       Laptop  North    Dell Laptop   1200
# 5  2023-03-12  Office Supplies          Pen  South       Ball Pen     20
# 6  2023-04-01        Furniture        Chair   East  Plastic Chair    150
# 7  2023-04-18       Technology        Phone   West  Samsung Phone    700
# 8  2023-05-10  Office Supplies        Paper  North       Notebook    100
# 9  2023-05-22        Furniture        Table  South    Study Table    400
# 10 2023-06-05       Technology       Laptop   East      HP Laptop   1100
# 11 2023-06-18  Office Supplies          Pen   West         Marker     30
#
#     Profit     Month profit_status
# 0       50   January        Profit
# 1      200   January        Profit
# 2       10  February        Profit
# 3      -20  February          loss
# 4      300     March        Profit
# 5        5     March        Profit
# 6       30     April        Profit
# 7      150     April        Profit
# 8       25       May        Profit
# 9       60       May        Profit
# 10     250      June        Profit
# 11       8      June        Profit

# %%
df['Sales'].sum()
# Out:
# np.int64(5050)

# %%
df.groupby('Category')['Sales'].sum()
# Out:
# Category
# Furniture          1050
# Office Supplies     200
# Technology         3800
# Name: Sales, dtype: int64

# %%
df.groupby('Region')['Sales'].sum()
# Out:
# Region
# East     1300
# North    1500
# South    1220
# West     1030
# Name: Sales, dtype: int64

# %%
df.to_excel("Cleaned_dataset.xlsx",index=False)
